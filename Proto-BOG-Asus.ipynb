# %%
import sys, os, re, unittest
import unicodedata
import json

# %%
def hasNumbers(inputString):
	return any(char.isdigit() for char in inputString)

# %%
def notALink(str):
	link = False

	if ".com" not in str and ".org" not in str:
		link = True
	if "http" not in str:
		link = link and True

	return link

# %%
def isNotPunctuation(punc):
    if punc != "." and punc != ")" and punc != "?" and punc != "!" and punc != "\"" and punc != "\'" and punc != ":":
        return True

# %%
def check_english_dict(valid_data):
	eng_dict = open("words_dictionary.json", "r")
	eng_dict_data = json.load(eng_dict)
	eng_dict.close()

	words = valid_data
	removed_words = []

	for i in range(len(words)):
		try:
			if eng_dict_data[words[i]] == 1:
				# words.remove(words[i])
				removed_words.append(words[i])

		except Exception as e:
			repr(e)

	# print removed_words

	try:
		wordsjson = open("removed_words.json", "r")
		rw_data = json.load(wordsjson)
		wordsjson.close()


		wordsjson = open("removed_words.json", "w")

		for removed_word in removed_words:
			rw_data[removed_word] = 1

		json.dump(rw_data, wordsjson)
		wordsjson.close()

	except Exception as e:
		print (repr(e))

	return words

# %%
def tokenizer(all_lines):
	count = 1
	corpus_data = {}
	prev_string = ""
	valid_data = []
	new = True
	curr_data = {}
	for line in all_lines:

		curr_line = line.split()
		# print curr_line, len(curr_line), curr_line[len(curr_line)-1]

		if count == 1:
# 			print (line)
			curr_data['title'] = line.upper()

		elif count == 2: #- gets the year of the date

			file_name = "corpus/"+curr_line[len(curr_line)-1]+"-corpus.json"

			if os.path.exists(file_name):
				type_action = "r"
				new = False
			else:
				type_action = "w"
				new = True

# 			print (file_name, new, type_action)

			
			
			if not new:
# 				print ("not new: " + file_name)
# 				corpus = open(file_name, "r")
# 				corpus_data = json.load(corpus)
				# print corpus_data
				# print "why"
				True
			else:
				True
# 				corpus = open(file_name, "w")
# 				corpus_data = {}
# 				corpus_data['corpus'] = []
				# json.dump(corpus_data-, corpus)
# 			corpus.close()

			curr_data['date'] = line

		elif count == 3:
			curr_data['author'] = line.upper()

		elif count > 3: # start to tokenize at line 4 of the current file

			written = False
			title = 0
			proper_noun = False
			if curr_line:
				for i in range( len(curr_line) ):
					curr_string = curr_line[i]
					written = False
					proper_noun = False
					
					if curr_string.istitle(): # if the first letter of the word is uppercase
						title = 1
						if prev_string is not "": 	# if the word is not the very first word of the document
							last_ch = prev_string[len(prev_string)-1]
							if isNotPunctuation(last_ch): 	# checks if the previous string has a period .
								proper_noun = True					# it's a proper noun if there is no . in the prev_str

						if not proper_noun:

							if not hasNumbers(curr_string) and notALink(curr_string):	# check if string does not have any number or any ".com" to signify a link
								cleaned_str = re.sub(r'[^A-Za-zÀ-ÿ.\\\'-]', '', curr_string)	# removes other characters that are not alphabet and selected symbols
								cleaned_str = cleaned_str.lower()
								
								if cleaned_str[len(cleaned_str)-1] == ".":
									cleaned_str = cleaned_str[:-1]

								# if cleaned_str not in valid_data:	# checks if current cleaned string is unique
								valid_data.append(cleaned_str)

								# corpus.write(cleaned_str +"\n")
								written = True

							else:
								written = False

					else:
						title = 2
						
						if not hasNumbers(curr_string) and notALink(curr_string): # check if string does not have any number or any ".com" to signify a link
							cleaned_str = re.sub(r'[^A-Za-z.\\\'-]', '', curr_string)
							cleaned_str = cleaned_str.lower()

							if len(cleaned_str) > 0:
								if cleaned_str[len(cleaned_str)-1] == ".":
									cleaned_str = cleaned_str[:-1]

								# json.dump(cleaned_str, corpus, ensure_ascii=False)
								# corpus.write(cleaned_str +"\n")
								
								# if cleaned_str not in valid_data: # checks if current cleaned string is unique
								valid_data.append(cleaned_str)

								written = True

						else:
							written = False

					# if written:
					# 	print curr_string, written, title, detect(curr_string.decode('utf-8').strip())
					# else:
					# 	print curr_string, written, title


					prev_string = curr_string

		count += 1

	valid_data = check_english_dict(valid_data)

	# print valid_data, "what"

	curr_data['words'] = valid_data

# 	corpus_data['corpus'].append(curr_data)
# 	corpus = open(file_name, "w")
# 	json.dump(corpus_data, corpus)
	# or
	# for vd in valid_data:
	# 	corpus.write(vd+"\n")

# 	corpus.close()
    
	tokenized_string = ""
    
# 	print (valid_data)

	for datum in valid_data:
# 		print (datum)
		tokenized_string = tokenized_string + datum + " "
    
	return tokenized_string

	# code for th-e unique corpus
	# if os.stat(UNIQUE_CORPUS).st_size > 2:
	# 	print "not empty"
	# 	with open(UNIQUE_CORPUS, mode = "r") as uc:
	# 		uc_data = json.load(uc)
	# 	uc.close()

	# 	with open(UNIQUE_CORPUS, mode = "w") as uc:
	# 		for curr_str in valid_data:
	# 			if curr_str not in uc_data:
	# 				uc_data.append(curr_str)
	# 		json.dump(uc_data, uc)

	# 	uc.close()
	# else:
	# 	with open(UNIQUE_CORPUS, mode = "w") as uc:
	# 		json.dump(valid_data, uc)
	# 	uc.close()

# %%
def main():
# 	path = "/home/cerasmae/Desktop/Celine-Thesis/cleaned-data";
	# https://stackoverflow.com/questions/30265592/list-directories-python-osx
	path = "/Users/rl-14/Desktop/Celine-Thesis/all-data/bomboradyo-scrape/error"
# 	path = "/Users/rl-14/Desktop/Celine-Thesis/all-data/cleaned-data"

	sys.path.append(path)
	# files = os.listdir(path)
	try:

		files = [x for x in os.listdir(path) if x.endswith(".txt")]
		count = 1
		# for file in files:
		# 	file_path = path+"/"+file

		# 	F = open(file_path, "r")

		# 	print(count, F)
		# 	count += 1

		for file in files:
			file_path = path+"/"+file
			# print file

			try:
				curr_file = open(file_path)
				lines = curr_file.read().splitlines()
				curr_file.close()
				# tokenizer(lines)

				# testing purposes-
# 				if count <= 5:
				print (count, file)
				tokenized = tokenizer(lines)
				example_corpus.append(tokenized)
					# check_duplicate()
					# for line in lines:
					# 	print line
# 				else:
# 					break
					# print count, file_path

			except Exception as e:
				print (repr(e)) 

			count += 1

	except IOError:
		print ("something is probably wrong with the path")

# %%
example_corpus = []
main()
# Out:
# 1  Korean Nationals sikop sa illegal online gaming potbet money muabot sa  million US Dollars.txt
# 2  Narra seedlings natanom sa mga miyembro sa KBP-Agusan del SurSurigao del Sur chapter sa th Oplan BroadcasTreeing.txt
# 3 Bag-ong Gensan OIC PNP city director SSupt. Berango pormal nang milingkod sa pwesto.txt
# 4 Bag-ong kaso sa HIVAIDS infection sa Butuan City midoble.txt
# 5 CdeO govtmay pinaskuhan sa Sendong survivorsPiso lot beneficiaries.txt
# 6 CdeO mayorLiquor banno aerial dronesipatuman sa BN traslacion.txt
# 7 DoH-target ang zero injuries sa X-Mas-NY .txt
# 8 Dul-an  ka mga masasupporters sa NPA misurrender sa kasundaluhan.txt
# 9 Gang-rapemurder casegitratar nga sulbad na sa CdeO.txt
# 10 IBP-MisOrCdeO chaptersupakon ang SC order sa Maute case hearing.txt
# 11 IBP-MisorIFIsupak sa Dutertes revolutionary govt proposal.txt
# 12 Kasundalohan nanghinaut nga ma-undang na ang dautang binuhatan sa CPPNPA.txt
# 13 Kontrobersyal nga si CIDG- regional director PSupt. Marcos ipatawag sunod sesyon sa Sangguniang Panglungsod.txt
# 14 Mga accomplishments sa administrasyon wala kaayo gilatag sa ikaduhang SONA ni Pangulong Duterte  gihatag nga grado-Cong. Acharon.txt
# 15 Million Volunteer Run suportado sa PRC-ButuanAgusan chapter.txt
# 16 MisOr-CdeO IBP sa impeachment case vs DuterteRobredo political circus.txt
# 17 NFA rice nga tag Pkilo subling mapalit sa mga palengke sa dakbayan ug sa IGaCos.txt
# 18 Pag-ban sa Rappler reporter pag-cover sa Malacaan presscon gikasubo sa NUJP-ButuanAgusan del Norte chapter.txt
# 19 Paghulip ni CSupt Espino sa PNP- gibakwi sa Camp Crame.txt
# 20 Passenger ship safety certificate sa MV Maria Olivia gisuspende sa MARINA-Caraga.txt
# 21 PASUCUSTP prexyilubong na sa CdeO.txt
# 22 Pickup nga may karga nga  unit sa slot machine tolendoy naharang sa kapulisan.txt
# 23 Pipila ka evacuees supak sa ML extensionlocalforeign aids nakasulod Marawi na.txt
# 24 PNP-AFPAll saintssouls day obserbvancegenerally peaceful.txt
# 25 Sakop sa KBGDragon Group patay sa engkuwentro sa Ozamiz City.txt
# 26 SRSupt. Beranggo mulingkod isip bag-ong OIC City Director sa GSCPO sugod sa Lunes.txt
# 27 UPDATE  mo nga batang masuso luwas na human naangin dihang gitigbas-patay ang inahan.txt
# 28 yo batang lalaki patay human nahagbong ug naligsan sa topdown.txt

# %%
# print (example_corpus)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

X = vectorizer.fit_transform(example_corpus) 
# print(X)
# print(vectorizer.get_feature_names())

count = 0

# for feature in vectorizer.get_feature_names():
#     print (count, feature)
#     count = count + 1

# %%
# print(vectorizer.vocabulary_)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

tfidf_vectorizer = TfidfVectorizer(min_df = 1)
TF_X = tfidf_vectorizer.fit_transform(example_corpus)
idf = tfidf_vectorizer.idf_

# %%
result_dict = dict(zip(tfidf_vectorizer.get_feature_names(), idf))
print (result_dict)
# Out:
# {'abli': 3.6741486494265287, 'ablihan': 3.6741486494265287, 'abogado': 3.2686835413183641, 'abot': 3.2686835413183641, 'abuso': 3.6741486494265287, 'access': 3.6741486494265287, 'accomplishment': 3.6741486494265287, 'accomplishments': 3.6741486494265287, 'acharon': 3.6741486494265287, 'activate': 3.6741486494265287, 'adiser': 3.6741486494265287, 'adlaw': 2.2878542883066384, 'adlawa': 2.2878542883066384, 'administrasyon': 3.6741486494265287, 'aduna': 3.2686835413183641, 'adunay': 2.9810014688665833, 'aerial': 3.6741486494265287, 'afp': 3.6741486494265287, 'afpall': 3.6741486494265287, 'ag': 3.6741486494265287, 'age': 3.6741486494265287, 'agian': 3.6741486494265287, 'aging': 3.6741486494265287, 'agreement': 3.6741486494265287, 'agusan': 3.6741486494265287, 'ahensiya': 3.6741486494265287, 'aids': 3.2686835413183641, 'akomodar': 3.6741486494265287, 'aksidente': 3.6741486494265287, 'aksyon': 3.6741486494265287, 'aktibidad': 3.6741486494265287, 'alang': 2.7578579175523736, 'alas': 2.7